# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

import time

# %%
from joblib import dump,load
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
des_list=['orb','sift','brisk']

orb=cv2.ORB_create()
sift=cv2.SIFT_create(nfeatures=500)
brisk=cv2.BRISK_create()

#orb=load('written_models/orb_descriptor.joblib')
#sift=load('written_models/sift_descriptor.joblib')
#brisk=load('written_models/brisk_descriptor.joblib')

# %%
descriptor=dict()

descriptor['orb']=orb
descriptor['sift']=sift
descriptor['brisk']=brisk

# %%
kmeans=dict()

for i in des_list:
    kmeans[i]=load(f'written_models/{i}_kmeans.joblib')

# %%
logreg=dict()
svm=dict()
randomforest=dict()

for i in des_list:
    logreg[i]=load(f'written_models/{i}_logreg.joblib')
    svm[i]=load(f'written_models/{i}_svm.joblib')
    randomforest[i]=load(f'written_models/{i}_randomforest.joblib')

# %%
def create_bag(labels_list):
    res=np.zeros((10*4,))
    for i in labels_list:
        res[i]+=1
    return res

def preprocess_image(img,estimator):
    img=cv2.resize( img, (img.shape[0]//4,img.shape[1]//4) )
    kp,des=descriptor[estimator].detectAndCompute(img,None)
    if(des is None):
        return None
    des=des.astype('float32')
    if(des.shape[0]>500):
        des=des[:500,:]
    kmeans_labels=kmeans[estimator].predict(des)
    bag_of_words=create_bag(kmeans_labels)
    return bag_of_words

# %%
movie_name="stepler.mp4"
#movie_name='karabin.mp4'
#movie_name='IMG_5360.MOV'

# %%
#LogisticRegression
cap=cv2.VideoCapture(movie_name)
print("Logistic Regression:")
counter=0

logreg_df=[]

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        #plt.imsave(f'frames_video/frame{counter}.png',frame)
        counter+=1
        
        vect=dict()
        temp_dict=dict()
        string=''
        for i in des_list:
            start_time=time.time()
            
            vect[i]=preprocess_image(frame,i)
            temp=vect[i].reshape((1,vect[i].shape[0]))
            pred=logreg[i].predict(temp)
            temp_dict[i]=pred
            
            delta_time=round(time.time()-start_time, 3)
            temp_dict[f'{i}_time']=delta_time
            string+=f'{delta_time}s {i}:{pred}\t'
        print(string)
        logreg_df.append(temp_dict)
    else:
        break
#закрыть захват видео
cap.release()
logreg_df=pd.DataFrame(logreg_df)
#print(logreg_df[:30])
# Out:
# Logistic Regression:
# 0.012s orb:['stepler']	0.074s sift:['hryvnia']	0.01s brisk:['trash']
# 0.015s orb:['stepler']	0.093s sift:['hryvnia']	0.011s brisk:['stepler']
# 0.016s orb:['stepler']	0.084s sift:['hryvnia']	0.009s brisk:['trash']
# 0.014s orb:['stepler']	0.097s sift:['hryvnia']	0.01s brisk:['trash']
# 0.019s orb:['stepler']	0.108s sift:['hryvnia']	0.013s brisk:['stepler']
# 0.019s orb:['stepler']	0.113s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.015s orb:['stepler']	0.071s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.016s orb:['stepler']	0.107s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.017s orb:['stepler']	0.102s sift:['hryvnia']	0.012s brisk:['stepler']
# 0.024s orb:['stepler']	0.107s sift:['hryvnia']	0.012s brisk:['trash']
# 0.021s orb:['stepler']	0.075s sift:['hryvnia']	0.011s brisk:['trash']
# 0.017s orb:['stepler']	0.085s sift:['hryvnia']	0.019s brisk:['trash']
# 0.016s orb:['stepler']	0.101s sift:['hryvnia']	0.022s brisk:['trash']
# 0.058s orb:['stepler']	0.124s sift:['hryvnia']	0.021s brisk:['stepler']
# 0.036s orb:['stepler']	0.08s sift:['hryvnia']	0.022s brisk:['trash']
# 0.045s orb:['stepler']	0.095s sift:['hryvnia']	0.01s brisk:['trash']
# 0.018s orb:['stepler']	0.074s sift:['hryvnia']	0.012s brisk:['trash']
# 0.018s orb:['stepler']	0.128s sift:['hryvnia']	0.01s brisk:['trash']
# 0.02s orb:['stepler']	0.076s sift:['hryvnia']	0.01s brisk:['trash']
# 0.018s orb:['stepler']	0.125s sift:['hryvnia']	0.012s brisk:['trash']
# 0.016s orb:['stepler']	0.081s sift:['hryvnia']	0.013s brisk:['trash']
# 0.025s orb:['stepler']	0.104s sift:['hryvnia']	0.011s brisk:['trash']
# 0.016s orb:['stepler']	0.075s sift:['hryvnia']	0.01s brisk:['trash']
# 0.016s orb:['stepler']	0.121s sift:['hryvnia']	0.009s brisk:['trash']
# 0.016s orb:['stepler']	0.085s sift:['hryvnia']	0.011s brisk:['stepler']
# 0.056s orb:['stepler']	0.09s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.021s orb:['stepler']	0.088s sift:['hryvnia']	0.02s brisk:['trash']
# 0.07s orb:['stepler']	0.081s sift:['hryvnia']	0.011s brisk:['stepler']
# 0.017s orb:['stepler']	0.121s sift:['hryvnia']	0.011s brisk:['stepler']
# 0.016s orb:['stepler']	0.117s sift:['hryvnia']	0.008s brisk:['trash']
# 0.013s orb:['stepler']	0.055s sift:['hryvnia']	0.007s brisk:['trash']
# 0.012s orb:['trash']	0.054s sift:['hryvnia']	0.007s brisk:['trash']
# 0.043s orb:['trash']	0.056s sift:['hryvnia']	0.007s brisk:['trash']
# 0.013s orb:['stepler']	0.061s sift:['hryvnia']	0.008s brisk:['trash']
# 0.014s orb:['trash']	0.055s sift:['hryvnia']	0.008s brisk:['trash']
# 0.038s orb:['trash']	0.06s sift:['hryvnia']	0.008s brisk:['trash']
# 0.015s orb:['hryvnia']	0.056s sift:['hryvnia']	0.008s brisk:['trash']
# 0.012s orb:['hryvnia']	0.055s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.018s orb:['trash']	0.056s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.012s orb:['trash']	0.059s sift:['hryvnia']	0.009s brisk:['trash']
# 0.032s orb:['hryvnia']	0.118s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.017s orb:['hryvnia']	0.055s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.021s orb:['hryvnia']	0.071s sift:['hryvnia']	0.008s brisk:['hryvnia']
# 0.054s orb:['hryvnia']	0.104s sift:['hryvnia']	0.008s brisk:['hryvnia']
# 0.021s orb:['hryvnia']	0.081s sift:['hryvnia']	0.01s brisk:['hryvnia']
# 0.043s orb:['stepler']	0.145s sift:['hryvnia']	0.028s brisk:['hryvnia']
# 0.062s orb:['hryvnia']	0.145s sift:['hryvnia']	0.011s brisk:['hryvnia']
# 0.027s orb:['stepler']	0.131s sift:['hryvnia']	0.013s brisk:['hryvnia']
# 0.063s orb:['trash']	0.086s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.021s orb:['trash']	0.109s sift:['hryvnia']	0.019s brisk:['hryvnia']
# 0.017s orb:['hryvnia']	0.116s sift:['hryvnia']	0.012s brisk:['hryvnia']
# 0.044s orb:['trash']	0.112s sift:['hryvnia']	0.013s brisk:['hryvnia']
# 0.071s orb:['trash']	0.12s sift:['hryvnia']	0.023s brisk:['hryvnia']
# 0.017s orb:['trash']	0.076s sift:['hryvnia']	0.009s brisk:['trash']
# 0.044s orb:['stepler']	0.107s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.029s orb:['trash']	0.064s sift:['hryvnia']	0.017s brisk:['hryvnia']
# 0.03s orb:['hryvnia']	0.128s sift:['hryvnia']	0.013s brisk:['hryvnia']
# 0.019s orb:['stepler']	0.092s sift:['hryvnia']	0.011s brisk:['hryvnia']
# 0.017s orb:['trash']	0.084s sift:['hryvnia']	0.014s brisk:['hryvnia']
# 0.017s orb:['stepler']	0.086s sift:['hryvnia']	0.011s brisk:['hryvnia']
# 0.016s orb:['trash']	0.099s sift:['hryvnia']	0.011s brisk:['hryvnia']
# 0.017s orb:['trash']	0.12s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.018s orb:['trash']	0.083s sift:['hryvnia']	0.019s brisk:['hryvnia']
# 0.036s orb:['trash']	0.151s sift:['hryvnia']	0.013s brisk:['hryvnia']
# 0.046s orb:['trash']	0.073s sift:['hryvnia']	0.022s brisk:['hryvnia']
# 0.014s orb:['trash']	0.067s sift:['hryvnia']	0.013s brisk:['trash']
# 0.014s orb:['trash']	0.067s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.019s orb:['trash']	0.098s sift:['trash']	0.018s brisk:['hryvnia']
# 0.014s orb:['stepler']	0.065s sift:['trash']	0.008s brisk:['hryvnia']
# 0.014s orb:['trash']	0.062s sift:['hryvnia']	0.026s brisk:['hryvnia']
# 0.014s orb:['trash']	0.067s sift:['stepler']	0.008s brisk:['trash']
# 0.015s orb:['trash']	0.093s sift:['hryvnia']	0.017s brisk:['hryvnia']
# 0.02s orb:['hryvnia']	0.103s sift:['hryvnia']	0.01s brisk:['hryvnia']
# 0.015s orb:['trash']	0.094s sift:['trash']	0.009s brisk:['hryvnia']
# 0.016s orb:['trash']	0.09s sift:['trash']	0.01s brisk:['trash']
# 0.018s orb:['trash']	0.103s sift:['trash']	0.01s brisk:['hryvnia']
# 0.015s orb:['trash']	0.077s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.017s orb:['trash']	0.066s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.017s orb:['hryvnia']	0.063s sift:['hryvnia']	0.027s brisk:['hryvnia']
# 0.027s orb:['hryvnia']	0.081s sift:['hryvnia']	0.015s brisk:['trash']
# 0.032s orb:['hryvnia']	0.108s sift:['stepler']	0.009s brisk:['trash']
# 0.022s orb:['hryvnia']	0.075s sift:['stepler']	0.01s brisk:['hryvnia']
# 0.03s orb:['trash']	0.082s sift:['hryvnia']	0.009s brisk:['trash']
# 0.04s orb:['trash']	0.082s sift:['trash']	0.01s brisk:['trash']
# 0.017s orb:['trash']	0.115s sift:['hryvnia']	0.015s brisk:['trash']
# 0.032s orb:['hryvnia']	0.089s sift:['hryvnia']	0.008s brisk:['hryvnia']
# 0.039s orb:['trash']	0.093s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.025s orb:['trash']	0.108s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.038s orb:['stepler']	0.074s sift:['hryvnia']	0.008s brisk:['hryvnia']
# 0.08s orb:['trash']	0.077s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.013s orb:['stepler']	0.053s sift:['hryvnia']	0.007s brisk:['hryvnia']
# 0.014s orb:['stepler']	0.053s sift:['hryvnia']	0.008s brisk:['hryvnia']
# 0.016s orb:['stepler']	0.096s sift:['hryvnia']	0.01s brisk:['trash']
# 0.018s orb:['stepler']	0.098s sift:['hryvnia']	0.012s brisk:['hryvnia']
# 0.02s orb:['stepler']	0.111s sift:['hryvnia']	0.014s brisk:['hryvnia']
# 0.03s orb:['stepler']	0.112s sift:['hryvnia']	0.015s brisk:['hryvnia']
# 0.058s orb:['stepler']	0.088s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.014s orb:['stepler']	0.06s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.023s orb:['stepler']	0.061s sift:['hryvnia']	0.023s brisk:['hryvnia']
# 0.034s orb:['stepler']	0.061s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.015s orb:['stepler']	0.06s sift:['hryvnia']	0.01s brisk:['hryvnia']
# 0.018s orb:['stepler']	0.062s sift:['hryvnia']	0.008s brisk:['hryvnia']
# 0.022s orb:['stepler']	0.06s sift:['hryvnia']	0.01s brisk:['hryvnia']
# 0.041s orb:['stepler']	0.061s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.013s orb:['stepler']	0.061s sift:['trash']	0.01s brisk:['hryvnia']
# 0.029s orb:['stepler']	0.069s sift:['hryvnia']	0.009s brisk:['hryvnia']
# 0.025s orb:['stepler']	0.149s sift:['hryvnia']	0.015s brisk:['hryvnia']
# 0.015s orb:['stepler']	0.089s sift:['hryvnia']	0.011s brisk:['hryvnia']

# %%
#SVM
cap=cv2.VideoCapture(movie_name)
print("SVM:")
counter=0

svm_df=[]

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        
        #plt.imsave(f'frames_video/frame{counter}.png',frame)
        counter+=1
        
        vect=dict()
        temp_dict=dict()
        string=''
        for i in des_list:
            start_time=time.time()
            vect[i]=preprocess_image(frame,i)
            temp=vect[i].reshape((1,vect[i].shape[0]))
            pred=svm[i].predict(temp)
            temp_dict[i]=pred
            
            delta_time=round( time.time()-start_time,3)
            temp_dict[f'{i}_time']=delta_time
            string+=f'{delta_time}s {i}:{pred}\t'
        print(string)
        svm_df.append(temp_dict)
    else:
        break
#закрыть захват видео
cap.release()
svm_df=pd.DataFrame(svm_df)
#print(svm_df[:30])
# Out:
# SVM:
# 0.023s orb:['stepler']	0.104s sift:['hryvnia']	0.009s brisk:['stepler']
# 0.049s orb:['stepler']	0.08s sift:['hryvnia']	0.011s brisk:['stepler']
# 0.033s orb:['stepler']	0.068s sift:['stepler']	0.01s brisk:['stepler']
# 0.019s orb:['stepler']	0.136s sift:['hryvnia']	0.016s brisk:['stepler']
# 0.059s orb:['stepler']	0.107s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.023s orb:['stepler']	0.079s sift:['hryvnia']	0.013s brisk:['stepler']
# 0.023s orb:['stepler']	0.093s sift:['hryvnia']	0.021s brisk:['stepler']
# 0.032s orb:['stepler']	0.075s sift:['stepler']	0.015s brisk:['stepler']
# 0.014s orb:['stepler']	0.088s sift:['hryvnia']	0.013s brisk:['stepler']
# 0.013s orb:['stepler']	0.091s sift:['stepler']	0.008s brisk:['stepler']
# 0.013s orb:['stepler']	0.069s sift:['stepler']	0.015s brisk:['stepler']
# 0.021s orb:['stepler']	0.058s sift:['hryvnia']	0.017s brisk:['stepler']
# 0.013s orb:['stepler']	0.089s sift:['hryvnia']	0.008s brisk:['stepler']
# 0.013s orb:['stepler']	0.063s sift:['hryvnia']	0.008s brisk:['stepler']
# 0.02s orb:['stepler']	0.103s sift:['hryvnia']	0.012s brisk:['stepler']
# 0.031s orb:['stepler']	0.096s sift:['hryvnia']	0.015s brisk:['stepler']
# 0.025s orb:['stepler']	0.103s sift:['stepler']	0.021s brisk:['stepler']
# 0.024s orb:['stepler']	0.097s sift:['karabin']	0.015s brisk:['stepler']
# 0.014s orb:['stepler']	0.109s sift:['hryvnia']	0.013s brisk:['stepler']
# 0.027s orb:['stepler']	0.122s sift:['stepler']	0.008s brisk:['stepler']
# 0.034s orb:['stepler']	0.06s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.013s orb:['stepler']	0.057s sift:['hryvnia']	0.008s brisk:['stepler']
# 0.028s orb:['stepler']	0.086s sift:['stepler']	0.012s brisk:['stepler']
# 0.016s orb:['stepler']	0.067s sift:['stepler']	0.01s brisk:['stepler']
# 0.033s orb:['stepler']	0.087s sift:['stepler']	0.016s brisk:['stepler']
# 0.026s orb:['stepler']	0.074s sift:['hryvnia']	0.014s brisk:['stepler']
# 0.03s orb:['stepler']	0.106s sift:['stepler']	0.009s brisk:['stepler']
# 0.016s orb:['stepler']	0.07s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.015s orb:['stepler']	0.105s sift:['stepler']	0.021s brisk:['stepler']
# 0.031s orb:['stepler']	0.126s sift:['stepler']	0.01s brisk:['stepler']
# 0.049s orb:['stepler']	0.07s sift:['hryvnia']	0.019s brisk:['stepler']
# 0.042s orb:['stepler']	0.152s sift:['hryvnia']	0.013s brisk:['stepler']
# 0.032s orb:['hryvnia']	0.106s sift:['hryvnia']	0.025s brisk:['stepler']
# 0.045s orb:['stepler']	0.071s sift:['hryvnia']	0.009s brisk:['stepler']
# 0.013s orb:['stepler']	0.148s sift:['trash']	0.01s brisk:['stepler']
# 0.02s orb:['stepler']	0.069s sift:['trash']	0.008s brisk:['stepler']
# 0.016s orb:['stepler']	0.093s sift:['trash']	0.016s brisk:['stepler']
# 0.022s orb:['stepler']	0.076s sift:['trash']	0.008s brisk:['stepler']
# 0.033s orb:['trash']	0.174s sift:['hryvnia']	0.022s brisk:['stepler']
# 0.081s orb:['stepler']	0.116s sift:['trash']	0.024s brisk:['stepler']
# 0.067s orb:['stepler']	0.102s sift:['trash']	0.044s brisk:['stepler']
# 0.026s orb:['hryvnia']	0.115s sift:['trash']	0.011s brisk:['stepler']
# 0.035s orb:['hryvnia']	0.091s sift:['hryvnia']	0.008s brisk:['stepler']
# 0.033s orb:['hryvnia']	0.133s sift:['trash']	0.011s brisk:['stepler']
# 0.015s orb:['hryvnia']	0.073s sift:['trash']	0.009s brisk:['stepler']
# 0.016s orb:['stepler']	0.089s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.025s orb:['stepler']	0.071s sift:['stepler']	0.01s brisk:['stepler']
# 0.016s orb:['stepler']	0.114s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.021s orb:['trash']	0.084s sift:['trash']	0.009s brisk:['stepler']
# 0.026s orb:['trash']	0.116s sift:['trash']	0.015s brisk:['hryvnia']
# 0.027s orb:['hryvnia']	0.097s sift:['hryvnia']	0.011s brisk:['stepler']
# 0.034s orb:['trash']	0.11s sift:['hryvnia']	0.009s brisk:['stepler']
# 0.015s orb:['trash']	0.064s sift:['hryvnia']	0.009s brisk:['stepler']
# 0.017s orb:['stepler']	0.106s sift:['stepler']	0.016s brisk:['stepler']
# 0.028s orb:['stepler']	0.067s sift:['hryvnia']	0.009s brisk:['stepler']
# 0.014s orb:['trash']	0.077s sift:['hryvnia']	0.018s brisk:['stepler']
# 0.026s orb:['hryvnia']	0.075s sift:['hryvnia']	0.01s brisk:['stepler']
# 0.018s orb:['stepler']	0.116s sift:['trash']	0.009s brisk:['hryvnia']
# 0.03s orb:['stepler']	0.118s sift:['hryvnia']	0.015s brisk:['hryvnia']
# 0.049s orb:['stepler']	0.113s sift:['hryvnia']	0.012s brisk:['hryvnia']
# 0.066s orb:['trash']	0.091s sift:['hryvnia']	0.008s brisk:['hryvnia']
# 0.013s orb:['trash']	0.091s sift:['hryvnia']	0.009s brisk:['trash']
# 0.016s orb:['trash']	0.057s sift:['hryvnia']	0.007s brisk:['stepler']
# 0.015s orb:['stepler']	0.082s sift:['karabin']	0.022s brisk:['hryvnia']
# 0.032s orb:['trash']	0.066s sift:['trash']	0.008s brisk:['stepler']
# 0.017s orb:['trash']	0.106s sift:['karabin']	0.008s brisk:['hryvnia']
# 0.045s orb:['trash']	0.09s sift:['karabin']	0.01s brisk:['trash']
# 0.031s orb:['trash']	0.113s sift:['trash']	0.012s brisk:['hryvnia']
# 0.036s orb:['stepler']	0.088s sift:['karabin']	0.012s brisk:['stepler']
# 0.016s orb:['stepler']	0.112s sift:['karabin']	0.012s brisk:['stepler']
# 0.017s orb:['trash']	0.085s sift:['stepler']	0.011s brisk:['trash']
# 0.018s orb:['trash']	0.083s sift:['stepler']	0.011s brisk:['hryvnia']
# 0.018s orb:['hryvnia']	0.1s sift:['hryvnia']	0.012s brisk:['trash']
# 0.049s orb:['hryvnia']	0.098s sift:['karabin']	0.011s brisk:['trash']
# 0.017s orb:['trash']	0.082s sift:['stepler']	0.011s brisk:['trash']
# 0.016s orb:['trash']	0.121s sift:['stepler']	0.009s brisk:['hryvnia']
# 0.02s orb:['trash']	0.073s sift:['stepler']	0.011s brisk:['trash']
# 0.015s orb:['trash']	0.075s sift:['stepler']	0.008s brisk:['trash']
# 0.026s orb:['trash']	0.085s sift:['stepler']	0.01s brisk:['hryvnia']
# 0.02s orb:['hryvnia']	0.117s sift:['stepler']	0.015s brisk:['trash']
# 0.018s orb:['hryvnia']	0.074s sift:['stepler']	0.009s brisk:['trash']
# 0.016s orb:['hryvnia']	0.13s sift:['stepler']	0.017s brisk:['trash']
# 0.029s orb:['trash']	0.08s sift:['stepler']	0.008s brisk:['trash']
# 0.03s orb:['trash']	0.077s sift:['stepler']	0.009s brisk:['hryvnia']
# 0.034s orb:['trash']	0.077s sift:['hryvnia']	0.008s brisk:['stepler']
# 0.029s orb:['hryvnia']	0.112s sift:['stepler']	0.016s brisk:['hryvnia']
# 0.036s orb:['trash']	0.085s sift:['stepler']	0.031s brisk:['hryvnia']
# 0.063s orb:['stepler']	0.115s sift:['stepler']	0.012s brisk:['hryvnia']
# 0.031s orb:['stepler']	0.114s sift:['stepler']	0.008s brisk:['hryvnia']
# 0.014s orb:['trash']	0.077s sift:['stepler']	0.012s brisk:['hryvnia']
# 0.037s orb:['stepler']	0.108s sift:['stepler']	0.013s brisk:['stepler']
# 0.025s orb:['stepler']	0.1s sift:['stepler']	0.016s brisk:['hryvnia']
# 0.026s orb:['stepler']	0.088s sift:['stepler']	0.007s brisk:['stepler']
# 0.019s orb:['stepler']	0.092s sift:['stepler']	0.016s brisk:['stepler']
# 0.023s orb:['stepler']	0.085s sift:['stepler']	0.011s brisk:['stepler']
# 0.09s orb:['stepler']	0.076s sift:['stepler']	0.019s brisk:['stepler']
# 0.029s orb:['stepler']	0.1s sift:['stepler']	0.015s brisk:['hryvnia']
# 0.067s orb:['stepler']	0.101s sift:['stepler']	0.01s brisk:['stepler']
# 0.017s orb:['stepler']	0.068s sift:['stepler']	0.013s brisk:['hryvnia']
# 0.02s orb:['stepler']	0.115s sift:['stepler']	0.018s brisk:['stepler']
# 0.017s orb:['stepler']	0.081s sift:['stepler']	0.023s brisk:['stepler']
# 0.016s orb:['stepler']	0.098s sift:['stepler']	0.011s brisk:['hryvnia']
# 0.031s orb:['stepler']	0.124s sift:['stepler']	0.009s brisk:['stepler']
# 0.015s orb:['stepler']	0.074s sift:['stepler']	0.011s brisk:['stepler']
# 0.015s orb:['stepler']	0.075s sift:['stepler']	0.02s brisk:['stepler']
# 0.031s orb:['stepler']	0.111s sift:['stepler']	0.015s brisk:['hryvnia']
# 0.032s orb:['stepler']	0.116s sift:['stepler']	0.01s brisk:['stepler']
# 0.05s orb:['stepler']	0.072s sift:['stepler']	0.01s brisk:['stepler']

# %%
#Random Forest
cap=cv2.VideoCapture(movie_name)
print("Random Forest:")
counter=0

randomforest_df=[]

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        counter+=1
        vect=dict()
        temp_dict=dict()
        string=''
        for i in des_list:
            start_time= time.time()
            vect[i]=preprocess_image(frame,i)
            temp=vect[i].reshape((1,vect[i].shape[0]))
            pred=randomforest[i].predict(temp)
            temp_dict[i]=pred
            
            delta_time=round(time.time()-start_time,3)
            temp_dict[f'{i}_time']=delta_time
            string+=f'{delta_time}s {i}:{pred}\t'
        print(string)
        randomforest_df.append(temp_dict)
    else:
        break
#закрыть захват видео
cap.release()
randomforest_df=pd.DataFrame(randomforest_df)
#print(randomforest_df[:30])
# Out:
# Random Forest:
# 0.133s orb:['stepler']	0.103s sift:['hryvnia']	0.054s brisk:['stepler']
# 0.077s orb:['stepler']	0.102s sift:['hryvnia']	0.046s brisk:['stepler']
# 0.051s orb:['stepler']	0.116s sift:['hryvnia']	0.063s brisk:['stepler']
# 0.076s orb:['stepler']	0.151s sift:['hryvnia']	0.067s brisk:['stepler']
# 0.111s orb:['stepler']	0.144s sift:['hryvnia']	0.059s brisk:['stepler']
# 0.09s orb:['stepler']	0.147s sift:['hryvnia']	0.056s brisk:['stepler']
# 0.135s orb:['stepler']	0.111s sift:['hryvnia']	0.053s brisk:['stepler']
# 0.086s orb:['stepler']	0.136s sift:['hryvnia']	0.081s brisk:['stepler']
# 0.076s orb:['stepler']	0.113s sift:['hryvnia']	0.068s brisk:['stepler']
# 0.064s orb:['stepler']	0.111s sift:['hryvnia']	0.102s brisk:['stepler']
# 0.055s orb:['stepler']	0.113s sift:['hryvnia']	0.066s brisk:['stepler']
# 0.128s orb:['stepler']	0.103s sift:['hryvnia']	0.08s brisk:['stepler']
# 0.082s orb:['stepler']	0.151s sift:['hryvnia']	0.072s brisk:['stepler']
# 0.126s orb:['stepler']	0.091s sift:['hryvnia']	0.055s brisk:['stepler']
# 0.086s orb:['stepler']	0.111s sift:['hryvnia']	0.074s brisk:['stepler']
# 0.07s orb:['stepler']	0.11s sift:['hryvnia']	0.042s brisk:['stepler']
# 0.044s orb:['stepler']	0.077s sift:['hryvnia']	0.035s brisk:['stepler']
# 0.121s orb:['stepler']	0.102s sift:['hryvnia']	0.05s brisk:['stepler']
# 0.09s orb:['stepler']	0.109s sift:['hryvnia']	0.057s brisk:['stepler']
# 0.064s orb:['stepler']	0.121s sift:['hryvnia']	0.066s brisk:['stepler']
# 0.087s orb:['stepler']	0.121s sift:['hryvnia']	0.082s brisk:['stepler']
# 0.14s orb:['stepler']	0.108s sift:['hryvnia']	0.063s brisk:['stepler']
# 0.062s orb:['stepler']	0.189s sift:['hryvnia']	0.053s brisk:['stepler']
# 0.139s orb:['stepler']	0.104s sift:['hryvnia']	0.077s brisk:['stepler']
# 0.081s orb:['stepler']	0.118s sift:['hryvnia']	0.057s brisk:['stepler']
# 0.11s orb:['stepler']	0.145s sift:['hryvnia']	0.031s brisk:['stepler']
# 0.047s orb:['stepler']	0.082s sift:['hryvnia']	0.036s brisk:['stepler']
# 0.088s orb:['stepler']	0.165s sift:['hryvnia']	0.06s brisk:['stepler']
# 0.138s orb:['stepler']	0.113s sift:['hryvnia']	0.05s brisk:['stepler']
# 0.081s orb:['stepler']	0.09s sift:['hryvnia']	0.041s brisk:['stepler']
# 0.048s orb:['stepler']	0.089s sift:['hryvnia']	0.057s brisk:['stepler']
# 0.093s orb:['stepler']	0.124s sift:['hryvnia']	0.07s brisk:['hryvnia']
# 0.067s orb:['stepler']	0.115s sift:['hryvnia']	0.052s brisk:['stepler']
# 0.164s orb:['stepler']	0.116s sift:['hryvnia']	0.08s brisk:['hryvnia']
# 0.127s orb:['karabin']	0.118s sift:['hryvnia']	0.1s brisk:['stepler']
# 0.135s orb:['stepler']	0.14s sift:['hryvnia']	0.057s brisk:['stepler']
# 0.078s orb:['stepler']	0.176s sift:['hryvnia']	0.07s brisk:['stepler']
# 0.085s orb:['stepler']	0.172s sift:['hryvnia']	0.071s brisk:['hryvnia']
# 0.078s orb:['hryvnia']	0.155s sift:['hryvnia']	0.041s brisk:['hryvnia']
# 0.06s orb:['stepler']	0.111s sift:['hryvnia']	0.069s brisk:['hryvnia']
# 0.052s orb:['stepler']	0.108s sift:['hryvnia']	0.073s brisk:['stepler']
# 0.052s orb:['hryvnia']	0.114s sift:['hryvnia']	0.046s brisk:['hryvnia']
# 0.067s orb:['hryvnia']	0.127s sift:['hryvnia']	0.078s brisk:['hryvnia']
# 0.052s orb:['hryvnia']	0.109s sift:['hryvnia']	0.05s brisk:['trash']
# 0.08s orb:['hryvnia']	0.104s sift:['hryvnia']	0.077s brisk:['hryvnia']
# 0.04s orb:['stepler']	0.089s sift:['hryvnia']	0.035s brisk:['hryvnia']
# 0.115s orb:['stepler']	0.1s sift:['hryvnia']	0.038s brisk:['hryvnia']
# 0.053s orb:['stepler']	0.085s sift:['hryvnia']	0.038s brisk:['hryvnia']
# 0.096s orb:['stepler']	0.126s sift:['hryvnia']	0.039s brisk:['hryvnia']
# 0.053s orb:['hryvnia']	0.135s sift:['hryvnia']	0.071s brisk:['hryvnia']
# 0.049s orb:['hryvnia']	0.107s sift:['hryvnia']	0.049s brisk:['trash']
# 0.067s orb:['hryvnia']	0.103s sift:['hryvnia']	0.066s brisk:['hryvnia']
# 0.065s orb:['stepler']	0.15s sift:['hryvnia']	0.101s brisk:['hryvnia']
# 0.072s orb:['stepler']	0.109s sift:['hryvnia']	0.05s brisk:['hryvnia']
# 0.159s orb:['stepler']	0.196s sift:['hryvnia']	0.063s brisk:['hryvnia']
# 0.097s orb:['hryvnia']	0.175s sift:['hryvnia']	0.034s brisk:['hryvnia']
# 0.052s orb:['hryvnia']	0.097s sift:['hryvnia']	0.085s brisk:['hryvnia']
# 0.119s orb:['hryvnia']	0.125s sift:['hryvnia']	0.061s brisk:['hryvnia']
# 0.054s orb:['stepler']	0.106s sift:['hryvnia']	0.051s brisk:['hryvnia']
# 0.114s orb:['stepler']	0.099s sift:['hryvnia']	0.049s brisk:['hryvnia']
# 0.079s orb:['hryvnia']	0.097s sift:['hryvnia']	0.053s brisk:['trash']
# 0.083s orb:['hryvnia']	0.133s sift:['hryvnia']	0.049s brisk:['trash']
# 0.05s orb:['stepler']	0.13s sift:['hryvnia']	0.054s brisk:['trash']
# 0.082s orb:['stepler']	0.11s sift:['hryvnia']	0.072s brisk:['trash']
# 0.073s orb:['stepler']	0.105s sift:['hryvnia']	0.105s brisk:['hryvnia']
# 0.056s orb:['stepler']	0.105s sift:['hryvnia']	0.067s brisk:['hryvnia']
# 0.078s orb:['stepler']	0.125s sift:['hryvnia']	0.087s brisk:['trash']
# 0.047s orb:['stepler']	0.1s sift:['hryvnia']	0.081s brisk:['hryvnia']
# 0.039s orb:['stepler']	0.104s sift:['trash']	0.041s brisk:['hryvnia']
# 0.093s orb:['stepler']	0.114s sift:['hryvnia']	0.047s brisk:['hryvnia']
# 0.102s orb:['stepler']	0.102s sift:['hryvnia']	0.044s brisk:['trash']
# 0.073s orb:['stepler']	0.107s sift:['hryvnia']	0.053s brisk:['hryvnia']
# 0.116s orb:['stepler']	0.13s sift:['hryvnia']	0.055s brisk:['hryvnia']
# 0.079s orb:['stepler']	0.121s sift:['hryvnia']	0.053s brisk:['hryvnia']
# 0.053s orb:['stepler']	0.096s sift:['hryvnia']	0.035s brisk:['hryvnia']
# 0.1s orb:['stepler']	0.133s sift:['hryvnia']	0.051s brisk:['hryvnia']
# 0.034s orb:['hryvnia']	0.096s sift:['hryvnia']	0.048s brisk:['hryvnia']
# 0.05s orb:['hryvnia']	0.082s sift:['stepler']	0.048s brisk:['hryvnia']
# 0.075s orb:['stepler']	0.104s sift:['hryvnia']	0.058s brisk:['hryvnia']
# 0.059s orb:['hryvnia']	0.154s sift:['stepler']	0.064s brisk:['hryvnia']
# 0.055s orb:['hryvnia']	0.119s sift:['hryvnia']	0.064s brisk:['hryvnia']
# 0.041s orb:['stepler']	0.105s sift:['hryvnia']	0.038s brisk:['hryvnia']
# 0.062s orb:['hryvnia']	0.11s sift:['hryvnia']	0.05s brisk:['hryvnia']
# 0.071s orb:['stepler']	0.104s sift:['hryvnia']	0.086s brisk:['hryvnia']
# 0.075s orb:['hryvnia']	0.091s sift:['hryvnia']	0.037s brisk:['hryvnia']
# 0.07s orb:['hryvnia']	0.139s sift:['hryvnia']	0.057s brisk:['hryvnia']
# 0.066s orb:['stepler']	0.112s sift:['stepler']	0.07s brisk:['hryvnia']
# 0.039s orb:['stepler']	0.099s sift:['hryvnia']	0.082s brisk:['hryvnia']
# 0.084s orb:['stepler']	0.106s sift:['hryvnia']	0.052s brisk:['hryvnia']
# 0.067s orb:['stepler']	0.11s sift:['hryvnia']	0.053s brisk:['hryvnia']
# 0.08s orb:['stepler']	0.106s sift:['hryvnia']	0.054s brisk:['hryvnia']
# 0.075s orb:['stepler']	0.133s sift:['hryvnia']	0.086s brisk:['hryvnia']
# 0.069s orb:['stepler']	0.115s sift:['hryvnia']	0.08s brisk:['trash']
# 0.071s orb:['stepler']	0.094s sift:['hryvnia']	0.047s brisk:['trash']
# 0.111s orb:['stepler']	0.106s sift:['stepler']	0.06s brisk:['hryvnia']
# 0.071s orb:['stepler']	0.142s sift:['stepler']	0.067s brisk:['hryvnia']
# 0.073s orb:['stepler']	0.126s sift:['hryvnia']	0.085s brisk:['hryvnia']
# 0.072s orb:['stepler']	0.112s sift:['stepler']	0.07s brisk:['hryvnia']
# 0.14s orb:['stepler']	0.115s sift:['stepler']	0.05s brisk:['hryvnia']
# 0.076s orb:['stepler']	0.087s sift:['hryvnia']	0.053s brisk:['stepler']
# 0.071s orb:['stepler']	0.096s sift:['hryvnia']	0.053s brisk:['hryvnia']
# 0.064s orb:['stepler']	0.111s sift:['hryvnia']	0.052s brisk:['hryvnia']
# 0.09s orb:['stepler']	0.105s sift:['hryvnia']	0.061s brisk:['hryvnia']
# 0.082s orb:['stepler']	0.101s sift:['hryvnia']	0.052s brisk:['stepler']
# 0.051s orb:['stepler']	0.082s sift:['hryvnia']	0.035s brisk:['hryvnia']
# 0.086s orb:['stepler']	0.114s sift:['hryvnia']	0.055s brisk:['hryvnia']
# 0.074s orb:['stepler']	0.112s sift:['hryvnia']	0.078s brisk:['hryvnia']
# 0.082s orb:['stepler']	0.109s sift:['hryvnia']	0.129s brisk:['hryvnia']

# %%
time_df=pd.DataFrame(columns=des_list)

time_df.loc['Logistic Regression']={'orb':logreg_df['orb_time'].mean(), \
                                    'sift':logreg_df['sift_time'].mean(),\
                                   'brisk':logreg_df['brisk_time'].mean()}

time_df.loc['SVM']={'orb':svm_df['orb_time'].mean(), \
                    'sift':svm_df['sift_time'].mean(),\
                    'brisk':svm_df['brisk_time'].mean()}

time_df.loc['Random Forest']={'orb':randomforest_df['orb_time'].mean(),\
                             'sift':randomforest_df['sift_time'].mean(),\
                             'brisk':randomforest_df['brisk_time'].mean()}
print(time_df)
# Out:
#                           orb      sift     brisk
# Logistic Regression  0.025130  0.088037  0.011630
# SVM                  0.027639  0.093648  0.012787
# Random Forest        0.080278  0.116167  0.060537

# %%
#рисование графиков
def get_label(label):
    if(label==['trash']):
        return 0
    if(label==['karabin']):
        return 2
    if(label==['stepler']):
        return 1
    if(label==['hryvnia']):
        return -1
def draw(labels_list,descr,clf):
    n=len(labels_list)
    label=get_label( labels_list[0] )
    xs=[0]
    ys=[label]
    for i in range(1,n):
        label=get_label( labels_list[i] )
        if(ys[-1]!=label):
            xs.append(i-1)
            ys.append(label)
        xs.append(i)
        ys.append(label)
    plt.figure(figsize=(30,10))
    plt.title(f"{descr}+{clf}",fontsize='xx-large')
    plt.plot(xs,ys,color='red')

# %%
#Logistic Regression
for i in des_list:
    draw(logreg_df[i],i,'Logistic Regression')

# %%
#SVM
for i in des_list:
    draw(svm_df[i],i,'SVM')

# %%
#Random Forest
for i in des_list:
    draw(randomforest_df[i],i,'Random Forest')
